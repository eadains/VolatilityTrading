# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.distributions import Categorical, Normal, MixtureSameFamily
from torch.optim.swa_utils import AveragedModel, SWALR

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

from datamodel import SPX, StockData
from model_testing import Model, WalkForwardAnalysis, create_lags
plt.rcParams["figure.figsize"] = (15,10)

# %%
class MDN(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim, n_components):
        """
        Mixture density network.
        in_dim: Number of input variables
        out_dim: Number of output variables
        hidden_dim: Size of hidden layer
        n_components: Number of normal distributions to use in mixture
        """
        super().__init__()
        self.n_components = n_components
        # Last layer output dimension rationale:
        # Need two parameters for each distribution thus 2 * n_components.
        # Need each of those for each output dimension, thus that multiplication
        self.norm_network = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ELU(),
            nn.Dropout(),
            nn.Linear(hidden_dim, 2 * n_components * out_dim),
        )
        self.cat_network = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ELU(),
            nn.Dropout(),
            nn.Linear(hidden_dim, n_components * out_dim),
        )

    def forward(self, x):
        norm_params = self.norm_network(x)
        # Split so we get parameters for mean and standard deviation
        mean, std = torch.split(norm_params, norm_params.shape[1] // 2, dim=1)
        # We need rightmost dimension to be n_components for mixture
        mean = mean.view(mean.shape[0], -1, self.n_components)
        std = std.view(std.shape[0], -1, self.n_components)
        normal = Normal(mean, torch.exp(std))

        cat_params = self.cat_network(x)
        # Again, rightmost dimension must be n_components
        cat = Categorical(
            logits=cat_params.view(cat_params.shape[0], -1, self.n_components)
        )

        return MixtureSameFamily(cat, normal)

# %%
class MDNModel(Model):
    def __init__(self, in_dim, out_dim, hidden_dim, n_components):
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.hidden_dim = hidden_dim
        self.n_components = n_components
        self.scaler = StandardScaler()
        
    def fit(self, train_indep_var, train_dep_var):
        self.model = MDN(self.in_dim, self.out_dim, self.hidden_dim, self.n_components)
        optim = torch.optim.Adam(self.model.parameters())
        
        self.scaler.fit(train_indep_var)
        train_indep_var = torch.tensor(self.scaler.transform(train_indep_var), dtype=torch.float32)
        train_dep_var = torch.tensor(train_dep_var, dtype=torch.float32).reshape(-1, 1)
        
        self.model.train()
        for epoch in range(2500):
            optim.zero_grad()
            output = self.model(train_indep_var)
            loss = -output.log_prob(train_dep_var).sum()
            loss.backward()
            optim.step()
            
            if epoch % 100 == 0:
                print(f"Epoch {epoch} complete. Loss: {loss}")
            
    def loss(self, test_indep_var, test_dep_var):
        indep_var_tensor = torch.tensor(self.scaler.transform(test_indep_var), dtype=torch.float32)
        dep_var_tensor = torch.tensor(test_dep_var, dtype=torch.float32).reshape(-1, 1)
        
        self.model.eval()
        output = self.model(indep_var_tensor)
        result = {"mean": pd.Series(output.mean.detach().squeeze().numpy(), index=test_indep_var.index),
                  "pit": output.cdf(dep_var_tensor).detach().numpy(),
                  "r2": r2_score(test_dep_var, output.mean.detach().numpy())}
        return result

# %%
spx = SPX()
data = StockData(["^VIX"])

spx_wk_prices = spx.prices.resample("W-FRI").last()
spx_wk_returns = (np.log(spx_wk_prices) - np.log(spx_wk_prices.shift(1))).dropna()
spx_wk_vol = np.sqrt(spx.vol.resample("W-FRI").sum())

# %%
spx_vol_lags = create_lags(np.log(np.sqrt(spx.vol)), 21, "spx_vol")
vix_lags = create_lags(np.log(data.prices.VIX["close"]), 21, "vix")
spx_return_lags = create_lags(spx.returns, 21, "spx_returns")

indep_var = pd.concat([spx_vol_lags, vix_lags, spx_return_lags], axis=1).dropna()
dep_var = np.log(spx_wk_vol.shift(-1).dropna())

common_index = indep_var.index.intersection(dep_var.index)

indep_var = indep_var.loc[common_index]
dep_var = dep_var.loc[common_index]

# %%
model = MDNModel(len(indep_var.columns), 1, 250, 5)
model_test = WalkForwardAnalysis(indep_var, dep_var, model, splits=25, min_samples=156)
results = model_test.walk_forward_test()

predicted = pd.concat([n["mean"] for n in results])
r2 = [n["r2"] for n in results]
# Out:
# Epoch 0 complete. Loss: 587.5673828125
# Epoch 100 complete. Loss: 141.20620727539062
# Epoch 200 complete. Loss: 93.30654907226562
# Epoch 300 complete. Loss: 68.67084503173828
# Epoch 400 complete. Loss: 50.159461975097656
# Epoch 500 complete. Loss: 49.854942321777344
# Epoch 600 complete. Loss: 44.075218200683594
# Epoch 700 complete. Loss: 59.64717483520508
# Epoch 800 complete. Loss: 25.371976852416992
# Epoch 900 complete. Loss: 27.184452056884766
# Epoch 1000 complete. Loss: 21.293527603149414
# Epoch 1100 complete. Loss: 30.879154205322266
# Epoch 1200 complete. Loss: 28.325302124023438
# Epoch 1300 complete. Loss: 10.244836807250977
# Epoch 1400 complete. Loss: 2.4468255043029785
# Epoch 1500 complete. Loss: 8.899739265441895
# Epoch 1600 complete. Loss: -7.07141637802124
# Epoch 1700 complete. Loss: 2.899371862411499
# Epoch 1800 complete. Loss: -0.8865352869033813
# Epoch 1900 complete. Loss: -9.78793716430664
# Epoch 2000 complete. Loss: -13.749171257019043
# Epoch 2100 complete. Loss: -2.889190435409546
# Epoch 2200 complete. Loss: -7.289758682250977
# Epoch 2300 complete. Loss: 1.4347895383834839
# Epoch 2400 complete. Loss: 2.1034865379333496
# Split 0 complete.
# Epoch 0 complete. Loss: 789.218505859375
# Epoch 100 complete. Loss: 180.08274841308594
# Epoch 200 complete. Loss: 115.84764099121094
# Epoch 300 complete. Loss: 81.85169219970703
# Epoch 400 complete. Loss: 67.97918701171875
# Epoch 500 complete. Loss: 48.54875183105469
# Epoch 600 complete. Loss: 48.2195930480957
# Epoch 700 complete. Loss: 33.848670959472656
# Epoch 800 complete. Loss: 37.58419418334961
# Epoch 900 complete. Loss: 37.66444778442383
# Epoch 1000 complete. Loss: 38.139244079589844
# Epoch 1100 complete. Loss: 28.786067962646484
# Epoch 1200 complete. Loss: 33.083316802978516
# Epoch 1300 complete. Loss: 19.35847282409668
# Epoch 1400 complete. Loss: 3.3675217628479004
# Epoch 1500 complete. Loss: 1.1680549383163452
# Epoch 1600 complete. Loss: 9.896894454956055
# Epoch 1700 complete. Loss: 10.402433395385742
# Epoch 1800 complete. Loss: 3.6605896949768066
# Epoch 1900 complete. Loss: 1.626023292541504
# Epoch 2000 complete. Loss: -5.418557167053223
# Epoch 2100 complete. Loss: 11.187359809875488
# Epoch 2200 complete. Loss: -15.549922943115234
# Epoch 2300 complete. Loss: -2.704167366027832
# Epoch 2400 complete. Loss: -8.162315368652344
# Split 1 complete.
# Epoch 0 complete. Loss: 942.0581665039062
# Epoch 100 complete. Loss: 241.20791625976562
# Epoch 200 complete. Loss: 144.55108642578125
# Epoch 300 complete. Loss: 104.20812225341797
# Epoch 400 complete. Loss: 83.44627380371094
# Epoch 500 complete. Loss: 74.10099792480469
# Epoch 600 complete. Loss: 49.946014404296875
# Epoch 700 complete. Loss: 49.86423873901367
# Epoch 800 complete. Loss: 46.150936126708984
# Epoch 900 complete. Loss: 40.13822555541992
# Epoch 1000 complete. Loss: 39.32987594604492
# Epoch 1100 complete. Loss: 31.977880477905273
# Epoch 1200 complete. Loss: 10.6376953125
# Epoch 1300 complete. Loss: 17.916641235351562
# Epoch 1400 complete. Loss: -9.020492553710938
# Epoch 1500 complete. Loss: 25.619550704956055
# Epoch 1600 complete. Loss: 0.18512797355651855
# Epoch 1700 complete. Loss: 9.68195915222168
# Epoch 1800 complete. Loss: 2.2468700408935547
# Epoch 1900 complete. Loss: 3.874765396118164
# Epoch 2000 complete. Loss: 2.2604312896728516
# Epoch 2100 complete. Loss: 15.979199409484863
# Epoch 2200 complete. Loss: -16.04969024658203
# Epoch 2300 complete. Loss: -7.849416732788086
# Epoch 2400 complete. Loss: -10.982514381408691
# Split 2 complete.
# Epoch 0 complete. Loss: 1160.029541015625
# Epoch 100 complete. Loss: 294.6997375488281
# Epoch 200 complete. Loss: 200.20550537109375
# Epoch 300 complete. Loss: 130.09364318847656
# Epoch 400 complete. Loss: 92.14522552490234
# Epoch 500 complete. Loss: 70.0826644897461
# Epoch 600 complete. Loss: 63.90149688720703
# Epoch 700 complete. Loss: 47.604393005371094
# Epoch 800 complete. Loss: 46.72472381591797
# Epoch 900 complete. Loss: 33.172119140625
# Epoch 1000 complete. Loss: 32.57574462890625
# Epoch 1100 complete. Loss: 18.52623748779297
# Epoch 1200 complete. Loss: 17.803464889526367
# Epoch 1300 complete. Loss: 34.363887786865234
# Epoch 1400 complete. Loss: 18.576841354370117
# Epoch 1500 complete. Loss: 12.285998344421387
# Epoch 1600 complete. Loss: -0.9596583843231201
# Epoch 1700 complete. Loss: -2.912771224975586
# Epoch 1800 complete. Loss: 22.19145393371582
# Epoch 1900 complete. Loss: -16.455408096313477
# Epoch 2000 complete. Loss: -16.56273651123047
# Epoch 2100 complete. Loss: -3.168720006942749
# Epoch 2200 complete. Loss: -18.554582595825195
# Epoch 2300 complete. Loss: -8.992152214050293
# Epoch 2400 complete. Loss: -10.432344436645508
# Split 3 complete.
# Epoch 0 complete. Loss: 1223.1258544921875
# Epoch 100 complete. Loss: 351.2400817871094
# Epoch 200 complete. Loss: 206.5804443359375
# Epoch 300 complete. Loss: 133.70855712890625
# Epoch 400 complete. Loss: 102.19544219970703
# Epoch 500 complete. Loss: 62.71414566040039
# Epoch 600 complete. Loss: 53.86195373535156
# Epoch 700 complete. Loss: 74.53096771240234
# Epoch 800 complete. Loss: 60.29780197143555
# Epoch 900 complete. Loss: 62.94680404663086
# Epoch 1000 complete. Loss: 43.944969177246094
# Epoch 1100 complete. Loss: 35.03480529785156
# Epoch 1200 complete. Loss: 36.24861145019531
# Epoch 1300 complete. Loss: 20.574909210205078
# Epoch 1400 complete. Loss: 14.306007385253906
# Epoch 1500 complete. Loss: 22.37596893310547
# Epoch 1600 complete. Loss: 1.6929290294647217
# Epoch 1700 complete. Loss: 27.385292053222656
# Epoch 1800 complete. Loss: -12.22689437866211
# Epoch 1900 complete. Loss: 11.876405715942383
# Epoch 2000 complete. Loss: -6.728782653808594
# Epoch 2100 complete. Loss: -7.631302833557129
# Epoch 2200 complete. Loss: 4.919271469116211
# Epoch 2300 complete. Loss: -29.62766456604004
# Epoch 2400 complete. Loss: -14.142667770385742
# Split 4 complete.
# Epoch 0 complete. Loss: 1423.992431640625
# Epoch 100 complete. Loss: 352.49298095703125
# Epoch 200 complete. Loss: 254.62838745117188
# Epoch 300 complete. Loss: 149.5529022216797
# Epoch 400 complete. Loss: 111.11695861816406
# Epoch 500 complete. Loss: 90.10407257080078
# Epoch 600 complete. Loss: 92.35865020751953
# Epoch 700 complete. Loss: 67.36009979248047
# Epoch 800 complete. Loss: 64.35234832763672
# Epoch 900 complete. Loss: 50.58045196533203
# Epoch 1000 complete. Loss: 49.26824188232422
# Epoch 1100 complete. Loss: 24.357826232910156
# Epoch 1200 complete. Loss: 53.25980758666992
# Epoch 1300 complete. Loss: 47.02357482910156
# Epoch 1400 complete. Loss: 30.91548728942871
# Epoch 1500 complete. Loss: 14.868779182434082
# Epoch 1600 complete. Loss: 40.3972053527832
# Epoch 1700 complete. Loss: 9.767745971679688
# Epoch 1800 complete. Loss: -12.619831085205078
# Epoch 1900 complete. Loss: -11.276026725769043
# Epoch 2000 complete. Loss: 6.1706085205078125
# Epoch 2100 complete. Loss: 0.1752939224243164
# Epoch 2200 complete. Loss: 4.672173500061035
# Epoch 2300 complete. Loss: 1.867152214050293
# Epoch 2400 complete. Loss: -21.988142013549805
# Split 5 complete.
# Epoch 0 complete. Loss: 1630.428955078125
# Epoch 100 complete. Loss: 417.2430114746094
# Epoch 200 complete. Loss: 266.5852355957031
# Epoch 300 complete. Loss: 187.06069946289062
# Epoch 400 complete. Loss: 151.48318481445312
# Epoch 500 complete. Loss: 118.79914855957031
# Epoch 600 complete. Loss: 98.97177124023438
# Epoch 700 complete. Loss: 70.83802795410156
# Epoch 800 complete. Loss: 81.888671875
# Epoch 900 complete. Loss: 59.571754455566406
# Epoch 1000 complete. Loss: 51.04640197753906
# Epoch 1100 complete. Loss: 45.749977111816406
# Epoch 1200 complete. Loss: 28.143081665039062
# Epoch 1300 complete. Loss: 30.862754821777344
# Epoch 1400 complete. Loss: 27.971416473388672
# Epoch 1500 complete. Loss: 19.78628158569336
# Epoch 1600 complete. Loss: 19.488168716430664
# Epoch 1700 complete. Loss: 15.344146728515625
# Epoch 1800 complete. Loss: 8.714951515197754
# Epoch 1900 complete. Loss: 0.3390326499938965
# Epoch 2000 complete. Loss: 16.581567764282227
# Epoch 2100 complete. Loss: 1.8478810787200928
# Epoch 2200 complete. Loss: -9.632194519042969
# Epoch 2300 complete. Loss: -3.134319543838501
# Epoch 2400 complete. Loss: -12.283788681030273
# Split 6 complete.
# Epoch 0 complete. Loss: 1835.4945068359375
# Epoch 100 complete. Loss: 476.11700439453125
# Epoch 200 complete. Loss: 274.51953125
# Epoch 300 complete. Loss: 198.1938934326172
# Epoch 400 complete. Loss: 164.937255859375
# Epoch 500 complete. Loss: 101.47222137451172
# Epoch 600 complete. Loss: 113.85343170166016
# Epoch 700 complete. Loss: 78.46526336669922
# Epoch 800 complete. Loss: 80.26988983154297
# Epoch 900 complete. Loss: 62.58032989501953
# Epoch 1000 complete. Loss: 39.9964714050293
# Epoch 1100 complete. Loss: 62.250274658203125
# Epoch 1200 complete. Loss: 29.67630958557129
# Epoch 1300 complete. Loss: 27.534671783447266
# Epoch 1400 complete. Loss: 50.39470291137695
# Epoch 1500 complete. Loss: 18.696922302246094
# Epoch 1600 complete. Loss: 12.961013793945312
# Epoch 1700 complete. Loss: -1.6950616836547852
# Epoch 1800 complete. Loss: -2.379537582397461
# Epoch 1900 complete. Loss: 17.377941131591797
# Epoch 2000 complete. Loss: -5.03093147277832
# Epoch 2100 complete. Loss: -14.95956802368164
# Epoch 2200 complete. Loss: -13.354177474975586
# Epoch 2300 complete. Loss: 13.350214004516602
# Epoch 2400 complete. Loss: -29.939260482788086
# Split 7 complete.
# Epoch 0 complete. Loss: 2062.799560546875
# Epoch 100 complete. Loss: 551.8571166992188
# Epoch 200 complete. Loss: 345.1923522949219
# Epoch 300 complete. Loss: 218.92835998535156
# Epoch 400 complete. Loss: 163.63812255859375
# Epoch 500 complete. Loss: 167.30517578125
# Epoch 600 complete. Loss: 107.9161376953125
# Epoch 700 complete. Loss: 108.33343505859375
# Epoch 800 complete. Loss: 93.59469604492188
# Epoch 900 complete. Loss: 74.05086517333984
# Epoch 1000 complete. Loss: 29.51417350769043
# Epoch 1100 complete. Loss: 70.11483001708984
# Epoch 1200 complete. Loss: 52.1668701171875
# Epoch 1300 complete. Loss: 31.32958984375
# Epoch 1400 complete. Loss: 12.073177337646484
# Epoch 1500 complete. Loss: 28.729400634765625
# Epoch 1600 complete. Loss: 33.25771713256836
# Epoch 1700 complete. Loss: 19.596342086791992
# Epoch 1800 complete. Loss: 0.17118144035339355
# Epoch 1900 complete. Loss: 35.7791748046875
# Epoch 2000 complete. Loss: 19.71520233154297
# Epoch 2100 complete. Loss: -1.420135259628296
# Epoch 2200 complete. Loss: 10.513592720031738
# Epoch 2300 complete. Loss: -19.211166381835938
# Epoch 2400 complete. Loss: -14.558209419250488
# Split 8 complete.
# Epoch 0 complete. Loss: 2163.03466796875
# Epoch 100 complete. Loss: 577.072265625
# Epoch 200 complete. Loss: 363.9378662109375
# Epoch 300 complete. Loss: 255.37966918945312
# Epoch 400 complete. Loss: 164.47702026367188
# Epoch 500 complete. Loss: 150.56121826171875
# Epoch 600 complete. Loss: 133.72634887695312
# Epoch 700 complete. Loss: 100.40911102294922
# Epoch 800 complete. Loss: 88.76895904541016
# Epoch 900 complete. Loss: 60.635013580322266
# Epoch 1000 complete. Loss: 74.46327209472656
# Epoch 1100 complete. Loss: 64.55221557617188
# Epoch 1200 complete. Loss: 66.31025695800781
# Epoch 1300 complete. Loss: 56.32688522338867
# Epoch 1400 complete. Loss: 51.94397735595703
# Epoch 1500 complete. Loss: 38.157737731933594
# Epoch 1600 complete. Loss: 52.19935607910156
# Epoch 1700 complete. Loss: 22.060632705688477
# Epoch 1800 complete. Loss: 16.282712936401367
# Epoch 1900 complete. Loss: 14.721080780029297
# Epoch 2000 complete. Loss: 10.252973556518555
# Epoch 2100 complete. Loss: 30.638595581054688
# Epoch 2200 complete. Loss: 35.21903610229492
# Epoch 2300 complete. Loss: 2.48390531539917
# Epoch 2400 complete. Loss: 3.1714131832122803
# Split 9 complete.
# Epoch 0 complete. Loss: 2473.668212890625
# Epoch 100 complete. Loss: 624.5430908203125
# Epoch 200 complete. Loss: 405.5231628417969
# Epoch 300 complete. Loss: 277.32342529296875
# Epoch 400 complete. Loss: 211.46885681152344
# Epoch 500 complete. Loss: 165.36160278320312
# Epoch 600 complete. Loss: 140.85354614257812
# Epoch 700 complete. Loss: 123.94534301757812
# Epoch 800 complete. Loss: 83.21446990966797
# Epoch 900 complete. Loss: 77.12495422363281
# Epoch 1000 complete. Loss: 78.43755340576172
# Epoch 1100 complete. Loss: 71.41716766357422
# Epoch 1200 complete. Loss: 76.22738647460938
# Epoch 1300 complete. Loss: 57.78113555908203
# Epoch 1400 complete. Loss: 69.33260345458984
# Epoch 1500 complete. Loss: 42.248077392578125
# Epoch 1600 complete. Loss: 38.617767333984375
# Epoch 1700 complete. Loss: 44.62163543701172
# Epoch 1800 complete. Loss: 4.883557319641113
# Epoch 1900 complete. Loss: 37.2749137878418
# Epoch 2000 complete. Loss: -1.2383098602294922
# Epoch 2100 complete. Loss: 14.52147102355957
# Epoch 2200 complete. Loss: 19.472272872924805
# Epoch 2300 complete. Loss: 16.62206268310547
# Epoch 2400 complete. Loss: 21.655414581298828
# Split 10 complete.
# Epoch 0 complete. Loss: 2252.269775390625
# Epoch 100 complete. Loss: 602.7189331054688
# Epoch 200 complete. Loss: 424.4814453125
# Epoch 300 complete. Loss: 323.8526916503906
# Epoch 400 complete. Loss: 246.4729461669922
# Epoch 500 complete. Loss: 178.41468811035156
# Epoch 600 complete. Loss: 135.3800048828125
# Epoch 700 complete. Loss: 150.05166625976562
# Epoch 800 complete. Loss: 111.04602813720703
# Epoch 900 complete. Loss: 115.03985595703125
# Epoch 1000 complete. Loss: 74.72843170166016
# Epoch 1100 complete. Loss: 76.84770202636719
# Epoch 1200 complete. Loss: 65.8978042602539
# Epoch 1300 complete. Loss: 107.06640625
# Epoch 1400 complete. Loss: 48.61914825439453
# Epoch 1500 complete. Loss: 61.423709869384766
# Epoch 1600 complete. Loss: 73.2693862915039
# Epoch 1700 complete. Loss: 33.53752136230469
# Epoch 1800 complete. Loss: 46.90916442871094
# Epoch 1900 complete. Loss: 25.314123153686523
# Epoch 2000 complete. Loss: 36.11854553222656
# Epoch 2100 complete. Loss: 16.091251373291016
# Epoch 2200 complete. Loss: -5.875411033630371
# Epoch 2300 complete. Loss: 12.87277889251709
# Epoch 2400 complete. Loss: -6.577472686767578
# Split 11 complete.
# Epoch 0 complete. Loss: 2995.55859375
# Epoch 100 complete. Loss: 724.9732055664062
# Epoch 200 complete. Loss: 490.86883544921875
# Epoch 300 complete. Loss: 351.39190673828125
# Epoch 400 complete. Loss: 243.86166381835938
# Epoch 500 complete. Loss: 202.16563415527344
# Epoch 600 complete. Loss: 217.1289520263672
# Epoch 700 complete. Loss: 169.3420867919922
# Epoch 800 complete. Loss: 148.92672729492188
# Epoch 900 complete. Loss: 123.32967376708984
# Epoch 1000 complete. Loss: 132.0587615966797
# Epoch 1100 complete. Loss: 68.96333312988281
# Epoch 1200 complete. Loss: 106.74942779541016
# Epoch 1300 complete. Loss: 89.28592681884766
# Epoch 1400 complete. Loss: 91.30974578857422
# Epoch 1500 complete. Loss: 54.53704833984375
# Epoch 1600 complete. Loss: 51.05486297607422
# Epoch 1700 complete. Loss: 67.637451171875
# Epoch 1800 complete. Loss: 70.78262329101562
# Epoch 1900 complete. Loss: 41.17805480957031
# Epoch 2000 complete. Loss: 23.933307647705078
# Epoch 2100 complete. Loss: 15.125174522399902
# Epoch 2200 complete. Loss: 36.2542724609375
# Epoch 2300 complete. Loss: -4.392941474914551
# Epoch 2400 complete. Loss: 33.44417190551758
# Split 12 complete.
# Epoch 0 complete. Loss: 2824.966064453125
# Epoch 100 complete. Loss: 737.3306884765625
# Epoch 200 complete. Loss: 489.8330078125
# Epoch 300 complete. Loss: 337.599853515625
# Epoch 400 complete. Loss: 247.24876403808594
# Epoch 500 complete. Loss: 202.9878692626953
# Epoch 600 complete. Loss: 166.59829711914062
# Epoch 700 complete. Loss: 147.64781188964844
# Epoch 800 complete. Loss: 118.63795471191406
# Epoch 900 complete. Loss: 130.85206604003906
# Epoch 1000 complete. Loss: 95.75511169433594
# Epoch 1100 complete. Loss: 91.11650085449219
# Epoch 1200 complete. Loss: 74.26103973388672
# Epoch 1300 complete. Loss: 85.86490631103516
# Epoch 1400 complete. Loss: 44.45183563232422
# Epoch 1500 complete. Loss: 76.49620056152344
# Epoch 1600 complete. Loss: 71.26888275146484
# Epoch 1700 complete. Loss: 62.79710388183594
# Epoch 1800 complete. Loss: 47.90348434448242
# Epoch 1900 complete. Loss: 36.064659118652344
# Epoch 2000 complete. Loss: 24.252527236938477
# Epoch 2100 complete. Loss: 9.301413536071777
# Epoch 2200 complete. Loss: 21.065034866333008
# Epoch 2300 complete. Loss: -3.037938117980957
# Epoch 2400 complete. Loss: 4.436143398284912
# Split 13 complete.
# Epoch 0 complete. Loss: 3061.3017578125
# Epoch 100 complete. Loss: 781.6437377929688
# Epoch 200 complete. Loss: 526.6966552734375
# Epoch 300 complete. Loss: 358.4523010253906
# Epoch 400 complete. Loss: 264.50091552734375
# Epoch 500 complete. Loss: 214.90411376953125
# Epoch 600 complete. Loss: 171.5559539794922
# Epoch 700 complete. Loss: 145.28018188476562
# Epoch 800 complete. Loss: 141.71829223632812
# Epoch 900 complete. Loss: 117.10456848144531
# Epoch 1000 complete. Loss: 104.2415771484375
# Epoch 1100 complete. Loss: 129.7279510498047
# Epoch 1200 complete. Loss: 69.04824829101562
# Epoch 1300 complete. Loss: 101.97998809814453
# Epoch 1400 complete. Loss: 115.12299346923828
# Epoch 1500 complete. Loss: 79.16804504394531
# Epoch 1600 complete. Loss: 59.2159538269043
# Epoch 1700 complete. Loss: 46.76924514770508
# Epoch 1800 complete. Loss: 56.34104919433594
# Epoch 1900 complete. Loss: 45.75819778442383
# Epoch 2000 complete. Loss: 27.04521942138672
# Epoch 2100 complete. Loss: 15.359336853027344
# Epoch 2200 complete. Loss: 8.006540298461914
# Epoch 2300 complete. Loss: 35.054439544677734
# Epoch 2400 complete. Loss: 31.27562141418457
# Split 14 complete.
# Epoch 0 complete. Loss: 3299.398681640625
# Epoch 100 complete. Loss: 850.5213623046875
# Epoch 200 complete. Loss: 564.3604736328125
# Epoch 300 complete. Loss: 382.26446533203125
# Epoch 400 complete. Loss: 292.82177734375
# Epoch 500 complete. Loss: 229.16165161132812
# Epoch 600 complete. Loss: 215.00408935546875
# Epoch 700 complete. Loss: 171.49969482421875
# Epoch 800 complete. Loss: 156.5992889404297
# Epoch 900 complete. Loss: 134.1753692626953
# Epoch 1000 complete. Loss: 169.97048950195312
# Epoch 1100 complete. Loss: 118.05110168457031
# Epoch 1200 complete. Loss: 96.2335433959961
# Epoch 1300 complete. Loss: 93.4701919555664
# Epoch 1400 complete. Loss: 80.23065185546875
# Epoch 1500 complete. Loss: 38.20534896850586
# Epoch 1600 complete. Loss: 74.43463897705078
# Epoch 1700 complete. Loss: 80.19357299804688
# Epoch 1800 complete. Loss: 62.783790588378906
# Epoch 1900 complete. Loss: 52.57096481323242
# Epoch 2000 complete. Loss: 17.84433364868164
# Epoch 2100 complete. Loss: 20.13811683654785
# Epoch 2200 complete. Loss: 9.929391860961914
# Epoch 2300 complete. Loss: -4.981611251831055
# Epoch 2400 complete. Loss: 11.001121520996094
# Split 15 complete.
# Epoch 0 complete. Loss: 4053.260986328125
# Epoch 100 complete. Loss: 933.667724609375
# Epoch 200 complete. Loss: 621.5676879882812
# Epoch 300 complete. Loss: 447.50335693359375
# Epoch 400 complete. Loss: 325.59619140625
# Epoch 500 complete. Loss: 270.8693542480469
# Epoch 600 complete. Loss: 250.763671875
# Epoch 700 complete. Loss: 197.19415283203125
# Epoch 800 complete. Loss: 171.04917907714844
# Epoch 900 complete. Loss: 131.41514587402344
# Epoch 1000 complete. Loss: 148.28793334960938
# Epoch 1100 complete. Loss: 121.27022552490234
# Epoch 1200 complete. Loss: 133.12313842773438
# Epoch 1300 complete. Loss: 118.60224151611328
# Epoch 1400 complete. Loss: 116.48186492919922
# Epoch 1500 complete. Loss: 91.08397674560547
# Epoch 1600 complete. Loss: 84.34590911865234
# Epoch 1700 complete. Loss: 91.84615325927734
# Epoch 1800 complete. Loss: 85.30632781982422
# Epoch 1900 complete. Loss: 72.76057434082031
# Epoch 2000 complete. Loss: 53.146827697753906
# Epoch 2100 complete. Loss: 67.66929626464844
# Epoch 2200 complete. Loss: 45.4807243347168
# Epoch 2300 complete. Loss: 70.7136001586914
# Epoch 2400 complete. Loss: 28.316957473754883
# Split 16 complete.
# Epoch 0 complete. Loss: 3906.8251953125
# Epoch 100 complete. Loss: 957.0403442382812
# Epoch 200 complete. Loss: 653.2679443359375
# Epoch 300 complete. Loss: 459.6223449707031
# Epoch 400 complete. Loss: 314.9451599121094
# Epoch 500 complete. Loss: 274.08673095703125
# Epoch 600 complete. Loss: 245.9241943359375
# Epoch 700 complete. Loss: 190.14036560058594
# Epoch 800 complete. Loss: 163.5863494873047
# Epoch 900 complete. Loss: 144.93614196777344
# Epoch 1000 complete. Loss: 146.87493896484375
# Epoch 1100 complete. Loss: 126.06025695800781
# Epoch 1200 complete. Loss: 113.41593170166016
# Epoch 1300 complete. Loss: 99.35345458984375
# Epoch 1400 complete. Loss: 60.81969451904297
# Epoch 1500 complete. Loss: 63.64488220214844
# Epoch 1600 complete. Loss: 81.28361511230469
# Epoch 1700 complete. Loss: 77.78180694580078
# Epoch 1800 complete. Loss: 44.53022003173828
# Epoch 1900 complete. Loss: 32.49732208251953
# Epoch 2000 complete. Loss: 30.928707122802734
# Epoch 2100 complete. Loss: 32.99672317504883
# Epoch 2200 complete. Loss: 32.76713943481445
# Epoch 2300 complete. Loss: 18.552288055419922
# Epoch 2400 complete. Loss: 39.1417236328125
# Split 17 complete.
# Epoch 0 complete. Loss: 3818.20703125
# Epoch 100 complete. Loss: 1006.9696044921875
# Epoch 200 complete. Loss: 633.4434204101562
# Epoch 300 complete. Loss: 436.69207763671875
# Epoch 400 complete. Loss: 357.6719970703125
# Epoch 500 complete. Loss: 272.57281494140625
# Epoch 600 complete. Loss: 249.81756591796875
# Epoch 700 complete. Loss: 188.86911010742188
# Epoch 800 complete. Loss: 177.27027893066406
# Epoch 900 complete. Loss: 146.37106323242188
# Epoch 1000 complete. Loss: 130.04881286621094
# Epoch 1100 complete. Loss: 133.830322265625
# Epoch 1200 complete. Loss: 156.3736572265625
# Epoch 1300 complete. Loss: 110.64723205566406
# Epoch 1400 complete. Loss: 97.31226348876953
# Epoch 1500 complete. Loss: 85.36257934570312
# Epoch 1600 complete. Loss: 63.2158088684082
# Epoch 1700 complete. Loss: 82.61424255371094
# Epoch 1800 complete. Loss: 46.235801696777344
# Epoch 1900 complete. Loss: 70.30006408691406
# Epoch 2000 complete. Loss: 72.74501037597656
# Epoch 2100 complete. Loss: 56.49318313598633
# Epoch 2200 complete. Loss: 37.6475715637207
# Epoch 2300 complete. Loss: 26.774412155151367
# Epoch 2400 complete. Loss: 30.54782485961914
# Split 18 complete.
# Epoch 0 complete. Loss: 4204.5888671875
# Epoch 100 complete. Loss: 1064.123291015625
# Epoch 200 complete. Loss: 696.4636840820312
# Epoch 300 complete. Loss: 500.97467041015625
# Epoch 400 complete. Loss: 394.7107849121094
# Epoch 500 complete. Loss: 321.47491455078125
# Epoch 600 complete. Loss: 264.50897216796875
# Epoch 700 complete. Loss: 240.5477752685547
# Epoch 800 complete. Loss: 181.27166748046875
# Epoch 900 complete. Loss: 139.86488342285156
# Epoch 1000 complete. Loss: 159.63201904296875
# Epoch 1100 complete. Loss: 137.15036010742188
# Epoch 1200 complete. Loss: 139.4639434814453
# Epoch 1300 complete. Loss: 130.59390258789062
# Epoch 1400 complete. Loss: 77.27373504638672
# Epoch 1500 complete. Loss: 122.13568115234375
# Epoch 1600 complete. Loss: 83.08052062988281
# Epoch 1700 complete. Loss: 47.58349609375
# Epoch 1800 complete. Loss: 80.60545349121094
# Epoch 1900 complete. Loss: 60.791603088378906
# Epoch 2000 complete. Loss: 66.96387481689453
# Epoch 2100 complete. Loss: 88.02313232421875
# Epoch 2200 complete. Loss: 55.45110321044922
# Epoch 2300 complete. Loss: 45.13695526123047
# Epoch 2400 complete. Loss: -2.9702086448669434
# Split 19 complete.
# Epoch 0 complete. Loss: 4028.140869140625
# Epoch 100 complete. Loss: 1046.88427734375
# Epoch 200 complete. Loss: 672.4834594726562
# Epoch 300 complete. Loss: 451.62066650390625
# Epoch 400 complete. Loss: 349.6188049316406
# Epoch 500 complete. Loss: 264.7704162597656
# Epoch 600 complete. Loss: 243.22848510742188
# Epoch 700 complete. Loss: 194.3907012939453
# Epoch 800 complete. Loss: 176.64996337890625
# Epoch 900 complete. Loss: 148.73448181152344
# Epoch 1000 complete. Loss: 140.89443969726562
# Epoch 1100 complete. Loss: 127.328857421875
# Epoch 1200 complete. Loss: 122.19293212890625
# Epoch 1300 complete. Loss: 134.13784790039062
# Epoch 1400 complete. Loss: 112.89200592041016
# Epoch 1500 complete. Loss: 87.24745178222656
# Epoch 1600 complete. Loss: 73.118896484375
# Epoch 1700 complete. Loss: 65.73313903808594
# Epoch 1800 complete. Loss: 60.80849838256836
# Epoch 1900 complete. Loss: 48.58845138549805
# Epoch 2000 complete. Loss: 57.33367156982422
# Epoch 2100 complete. Loss: 52.466617584228516
# Epoch 2200 complete. Loss: 11.05982494354248
# Epoch 2300 complete. Loss: 21.53380012512207
# Epoch 2400 complete. Loss: 39.105281829833984
# Split 20 complete.
# Epoch 0 complete. Loss: 4472.78662109375
# Epoch 100 complete. Loss: 1168.544189453125
# Epoch 200 complete. Loss: 721.2828369140625
# Epoch 300 complete. Loss: 474.8385009765625
# Epoch 400 complete. Loss: 373.2902526855469
# Epoch 500 complete. Loss: 298.826171875
# Epoch 600 complete. Loss: 258.33721923828125
# Epoch 700 complete. Loss: 242.29612731933594
# Epoch 800 complete. Loss: 179.77951049804688
# Epoch 900 complete. Loss: 181.9532012939453
# Epoch 1000 complete. Loss: 166.6202850341797
# Epoch 1100 complete. Loss: 147.91981506347656
# Epoch 1200 complete. Loss: 160.72817993164062
# Epoch 1300 complete. Loss: 148.13014221191406
# Epoch 1400 complete. Loss: 97.06932067871094
# Epoch 1500 complete. Loss: 101.21270751953125
# Epoch 1600 complete. Loss: 80.92453002929688
# Epoch 1700 complete. Loss: 53.678462982177734
# Epoch 1800 complete. Loss: 84.6376953125
# Epoch 1900 complete. Loss: 52.83209228515625
# Epoch 2000 complete. Loss: 61.50011444091797
# Epoch 2100 complete. Loss: 73.71192932128906
# Epoch 2200 complete. Loss: 60.81414794921875
# Epoch 2300 complete. Loss: 52.149940490722656
# Epoch 2400 complete. Loss: 4.554351806640625
# Split 21 complete.
# Epoch 0 complete. Loss: 4584.79931640625
# Epoch 100 complete. Loss: 1212.6524658203125
# Epoch 200 complete. Loss: 770.1835327148438
# Epoch 300 complete. Loss: 512.523681640625
# Epoch 400 complete. Loss: 388.3760070800781
# Epoch 500 complete. Loss: 322.658447265625
# Epoch 600 complete. Loss: 276.5478820800781
# Epoch 700 complete. Loss: 262.0019836425781
# Epoch 800 complete. Loss: 222.2718505859375
# Epoch 900 complete. Loss: 184.99935913085938
# Epoch 1000 complete. Loss: 159.25547790527344
# Epoch 1100 complete. Loss: 163.84536743164062
# Epoch 1200 complete. Loss: 167.52606201171875
# Epoch 1300 complete. Loss: 116.874755859375
# Epoch 1400 complete. Loss: 95.47280883789062
# Epoch 1500 complete. Loss: 96.34452056884766
# Epoch 1600 complete. Loss: 105.00495910644531
# Epoch 1700 complete. Loss: 98.64681243896484
# Epoch 1800 complete. Loss: 115.0996322631836
# Epoch 1900 complete. Loss: 65.56531524658203
# Epoch 2000 complete. Loss: 41.17733383178711
# Epoch 2100 complete. Loss: 74.94695281982422
# Epoch 2200 complete. Loss: 45.605628967285156
# Epoch 2300 complete. Loss: 51.65312957763672
# Epoch 2400 complete. Loss: 41.20006561279297
# Split 22 complete.
# Epoch 0 complete. Loss: 4748.04931640625
# Epoch 100 complete. Loss: 1152.58203125
# Epoch 200 complete. Loss: 762.4281616210938
# Epoch 300 complete. Loss: 539.4955444335938
# Epoch 400 complete. Loss: 387.6844482421875
# Epoch 500 complete. Loss: 306.03363037109375
# Epoch 600 complete. Loss: 282.62567138671875
# Epoch 700 complete. Loss: 227.95835876464844
# Epoch 800 complete. Loss: 222.52455139160156
# Epoch 900 complete. Loss: 175.94369506835938
# Epoch 1000 complete. Loss: 187.41009521484375
# Epoch 1100 complete. Loss: 117.86920166015625
# Epoch 1200 complete. Loss: 166.2467803955078
# Epoch 1300 complete. Loss: 160.4757537841797
# Epoch 1400 complete. Loss: 77.02151489257812
# Epoch 1500 complete. Loss: 141.42926025390625
# Epoch 1600 complete. Loss: 128.06942749023438
# Epoch 1700 complete. Loss: 131.13241577148438
# Epoch 1800 complete. Loss: 74.08306121826172
# Epoch 1900 complete. Loss: 38.91974639892578
# Epoch 2000 complete. Loss: 63.142127990722656
# Epoch 2100 complete. Loss: 66.63922119140625
# Epoch 2200 complete. Loss: 79.27547454833984
# Epoch 2300 complete. Loss: 78.24360656738281
# Epoch 2400 complete. Loss: 49.2848014831543
# Split 23 complete.

# %%
np.exp(predicted).plot()
np.exp(dep_var).plot()
# Out:
# <AxesSubplot:>
